# %% [markdown]
# ### Dataset Link: https://www.kaggle.com/columbine/imdb-dataset-sentiment-analysis-in-csv-format
#
# Sentiment Analysis can help us finding out the mood and emotions of general a customer or reviewer and it helps in gathering the insightful information regarding the context. Sentiment Analysis is a process of analyzing data and classifying it based on the need of the research.

# %%
import pandas as pd
from textblob import TextBlob
from nltk.tokenize.toktok import ToktokTokenizer
import re
tokenizer = ToktokTokenizer()
import spacy
nlp = spacy.load('en_core_web_sm', disable=['ner'])

# %%
TextBlob("he is very good boy").sentiment
# Out:
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)

# %%
TextBlob("he is not a good boy").sentiment
# Out:
# Sentiment(polarity=-0.35, subjectivity=0.6000000000000001)

# %%
TextBlob("Everybody says this man is poor").sentiment
# Out:
# Sentiment(polarity=-0.4, subjectivity=0.6)

# %%
### Data Loading
train=pd.read_csv("/content/Train.csv")
train
# Out:
#                                                     text  label
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
# [40000 rows x 2 columns]

# %%
label_0=train[train['label']==0].sample(n=5000)
label_1=train[train['label']==1].sample(n=5000)

# %%
train=pd.concat([label_1,label_0])
from sklearn.utils import shuffle
train = shuffle(train)

# %%
train
# Out:
#                                                     text  label
# 3470   You looking for a comic drama with suspense an...      1
# 30266  This is 30 minute show about one joke. The jok...      0
# 35079  his costume drama is ill cast and without char...      0
# 25073  This movie was based on actual fact? I sincere...      0
# 32516  When commenting on this film, one must realise...      1
# ...                                                  ...    ...
# 38181  This is hardly a movie at all, but rather a re...      1
# 16180  Sad story of a downed B-17 pilot. Brady is sho...      1
# 38293  This movie was a sicky sweet cutesy romantic c...      1
# 24308  i am not exactly how sure the accuracy is with...      1
# 32208  Before you dismiss my post as "not getting it"...      0
#
# [10000 rows x 2 columns]

# %% [markdown]
# Here, the data has two labels ie 0 and 1. 0 stands for "Negative" and "1" stands for "Positive".

# %% [markdown]
# ### Data Preprocessing

# %%
train.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
" "
# Out:
# ' '

# %%
import numpy as np
train.replace(r'^\s*$', np.nan, regex=True,inplace=True)
train.dropna(axis = 0, how = 'any', inplace = True)

# %%
train.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)
print('escape seq removed')
# Out:
# escape seq removed

# %%
import numpy as np
train.replace(r'^\s*$', np.nan, regex=True,inplace=True)
train.dropna(axis = 0, how = 'any', inplace = True)

# %%
train
# Out:
#                                                     text  label
# 3470   You looking for a comic drama with suspense an...      1
# 30266  This is 30 minute show about one joke. The jok...      0
# 35079  his costume drama is ill cast and without char...      0
# 25073  This movie was based on actual fact? I sincere...      0
# 32516  When commenting on this film, one must realise...      1
# ...                                                  ...    ...
# 38181  This is hardly a movie at all, but rather a re...      1
# 16180  Sad story of a downed B-17 pilot. Brady is sho...      1
# 38293  This movie was a sicky sweet cutesy romantic c...      1
# 24308  i am not exactly how sure the accuracy is with...      1
# 32208  Before you dismiss my post as "not getting it"...      0
#
# [10000 rows x 2 columns]

# %%
train['text']=train['text'].str.encode('ascii', 'ignore').str.decode('ascii')
print('non-ascii data removed')
# Out:
# non-ascii data removed

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    import string
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text
train['text']=train['text'].apply(remove_punctuations)

# %%
train
# Out:
#                                                     text  label
# 3470   You looking for a comic drama with suspense an...      1
# 30266  This is 30 minute show about one joke The joke...      0
# 35079  his costume drama is ill cast and without char...      0
# 25073  This movie was based on actual fact I sincerel...      0
# 32516  When commenting on this film one must realise ...      1
# ...                                                  ...    ...
# 38181  This is hardly a movie at all but rather a rea...      1
# 16180  Sad story of a downed B17 pilot Brady is shot ...      1
# 38293  This movie was a sicky sweet cutesy romantic c...      1
# 24308  i am not exactly how sure the accuracy is with...      1
# 32208  Before you dismiss my post as not getting it l...      0
#
# [10000 rows x 2 columns]

# %%
# !python -m nltk.downloader stopwords
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
def custom_remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %%
train['text']=train['text'].apply(custom_remove_stopwords)

# %%
train
# Out:
#                                                     text  label
# 3470   looking comic drama suspense ensemble cast Wel...      1
# 30266  30 minute show one joke joke Cavemen not treat...      0
# 35079  costume drama ill cast without charmbr br Geor...      0
# 25073  movie based actual fact sincerely hope notbr b...      0
# 32516  commenting film one must realise based true st...      1
# ...                                                  ...    ...
# 38181  hardly movie rather real vaudeville show filme...      1
# 16180  Sad story downed B17 pilot Brady shot occupied...      1
# 38293  movie sicky sweet cutesy romantic comedy kind ...      1
# 24308  not exactly sure accuracy movie tell thoroughl...      1
# 32208  dismiss post not getting let sayIm one biggest...      0
#
# [10000 rows x 2 columns]

# %%
def remove_special_characters(text):
    text = re.sub('[^a-zA-z0-9\s]', '', text)
    return text

# %%
train['text']=train['text'].apply(remove_special_characters)

# %%
def remove_html(text):
    import re
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r' ', text)

# %%
train['text']=train['text'].apply(remove_html)

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r' ',text)

# %%
train['text']=train['text'].apply(remove_URL)

# %%
def remove_numbers(text):
    """ Removes integers """
    text = ''.join([i for i in text if not i.isdigit()])
    return text

# %%
train['text']=train['text'].apply(remove_numbers)

# %%
def cleanse(word):
    rx = re.compile(r'\D*\d')
    if rx.match(word):
        return ''
    return word
def remove_alphanumeric(strings):
    nstrings = [" ".join(filter(None, (
    cleanse(word) for word in string.split())))
    for string in strings.split()]
    str1 = ' '.join(nstrings)
    return str1

# %%
train['text']=train['text'].apply(remove_alphanumeric)

# %%
train
# Out:
#                                                     text  label
# 3470   looking comic drama suspense ensemble cast Wel...      1
# 30266  minute show one joke joke Cavemen not treated ...      0
# 35079  costume drama ill cast without charmbr br Geor...      0
# 25073  movie based actual fact sincerely hope notbr b...      0
# 32516  commenting film one must realise based true st...      1
# ...                                                  ...    ...
# 38181  hardly movie rather real vaudeville show filme...      1
# 16180  Sad story downed B pilot Brady shot occupied t...      1
# 38293  movie sicky sweet cutesy romantic comedy kind ...      1
# 24308  not exactly sure accuracy movie tell thoroughl...      1
# 32208  dismiss post not getting let sayIm one biggest...      0
#
# [10000 rows x 2 columns]

# %%
def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

# %%
train['text']=train['text'].apply(lemmatize_text)

# %%
train['sentiment'] = train['text'].apply(lambda tweet: TextBlob(tweet).sentiment)

# %%
train
# Out:
#                                                     text  label  \
# 10204  Uh oh Another gay film time showing black side...      0
# 28500  case youre wondering buffoonish Loren Cn Crypt...      0
# 34313  must see film great dialogues great music grea...      1
# 7195   film not fail engage move even audience famili...      1
# 22891  watching Next Action Star reality TV series pl...      1
# ...                                                  ...    ...
# 25690  Theres really no way beat around bush saying L...      0
# 15506  Okay struggled set aside fact selling EVP real...      0
# 20273  mind boggles exactly Universal Soldier merited...      0
# 11102  saw movie Tribeca Film Festival say thought am...      1
# 24390  Ernst Lubitsch gave us wonderful films like De...      1
#
#                                         sentiment
# 10204   (0.0831932773109244, 0.39383753501400554)
# 28500   (-0.4166666666666667, 0.6095238095238096)
# 34313   (0.39841269841269844, 0.6341269841269841)
# 7195     (0.2032271944922547, 0.4665232358003442)
# 22891   (0.20686456400742112, 0.5181199752628324)
# ...                                           ...
# 25690  (-0.08806216931216931, 0.3828703703703704)
# 15506   (0.09909090909090905, 0.4511111111111112)
# 20273    (0.09144283746556475, 0.452347337006428)
# 11102     (0.390909090909091, 0.5636363636363636)
# 24390   (0.33151260504201685, 0.7158263305322129)
#
# [10000 rows x 3 columns]

# %%
# sentiment_series = train['sentiment'].tolist()
if 'sentiment' not in train.columns:
    train['sentiment'] = train['text'].apply(lambda tweet: TextBlob(tweet).sentiment)

# %%
# ipython-input-42-1478f65d021d
sentiment_series = train['sentiment'].tolist()

# ipython-input-41-1478f65d021d
columns = ['polarity', 'subjectivity']
df1 = pd.DataFrame(sentiment_series, columns=columns, index=train.index)

# %%
df1
# Out:
#        polarity  subjectivity
# 3470   0.097500      0.550000
# 30266  0.001407      0.502489
# 35079  0.205882      0.679657
# 25073  0.073039      0.494608
# 32516  0.009259      0.474074
# ...         ...           ...
# 38181  0.361667      0.676111
# 16180 -0.031111      0.582778
# 38293  0.154621      0.538939
# 24308  0.140625      0.524306
# 32208 -0.097362      0.569227
#
# [10000 rows x 2 columns]

# %%
result = pd.concat([train,df1],axis=1)

# %%
result.drop(['sentiment'],axis=1,inplace=True)

# %%
result.loc[result['polarity']>=0.3, 'Sentiment'] = "Positive"
result.loc[result['polarity']<0.3, 'Sentiment'] = "Negative"

# %%
result
# Out:
#                                                     text  label  polarity  \
# 3470   look comic drama suspense ensemble cast well l...      1  0.097500
# 30266  minute show one joke joke Cavemen not treat fa...      0  0.001407
# 35079  costume drama ill cast without charmbr br Geor...      0  0.205882
# 25073  movie base actual fact sincerely hope notbr br...      0  0.073039
# 32516  comment film one must realise base true story ...      1  0.009259
# ...                                                  ...    ...       ...
# 38181  hardly movie rather real vaudeville show film ...      1  0.361667
# 16180  sad story down B pilot Brady shoot occupy terr...      1 -0.031111
# 38293  movie sicky sweet cutesy romantic comedy kind ...      1  0.154621
# 24308  not exactly sure accuracy movie tell thoroughl...      1  0.140625
# 32208  dismiss post not getting let sayIm one big Ric...      0 -0.097362
#
#        subjectivity Sentiment
# 3470       0.550000  Negative
# 30266      0.502489  Negative
# 35079      0.679657  Negative
# 25073      0.494608  Negative
# 32516      0.474074  Negative
# ...             ...       ...
# 38181      0.676111  Positive
# 16180      0.582778  Negative
# 38293      0.538939  Negative
# 24308      0.524306  Negative
# 32208      0.569227  Negative
#
# [10000 rows x 5 columns]

# %%
result.loc[result['label']==1, 'Sentiment_label'] = 1
result.loc[result['label']==0, 'Sentiment_label'] = 0

# %%
result
# Out:
#                                                     text  label  polarity  \
# 3470   look comic drama suspense ensemble cast well l...      1  0.097500
# 30266  minute show one joke joke Cavemen not treat fa...      0  0.001407
# 35079  costume drama ill cast without charmbr br Geor...      0  0.205882
# 25073  movie base actual fact sincerely hope notbr br...      0  0.073039
# 32516  comment film one must realise base true story ...      1  0.009259
# ...                                                  ...    ...       ...
# 38181  hardly movie rather real vaudeville show film ...      1  0.361667
# 16180  sad story down B pilot Brady shoot occupy terr...      1 -0.031111
# 38293  movie sicky sweet cutesy romantic comedy kind ...      1  0.154621
# 24308  not exactly sure accuracy movie tell thoroughl...      1  0.140625
# 32208  dismiss post not getting let sayIm one big Ric...      0 -0.097362
#
#        subjectivity Sentiment  Sentiment_label
# 3470       0.550000  Negative              1.0
# 30266      0.502489  Negative              0.0
# 35079      0.679657  Negative              0.0
# 25073      0.494608  Negative              0.0
# 32516      0.474074  Negative              1.0
# ...             ...       ...              ...
# 38181      0.676111  Positive              1.0
# 16180      0.582778  Negative              1.0
# 38293      0.538939  Negative              1.0
# 24308      0.524306  Negative              1.0
# 32208      0.569227  Negative              0.0
#
# [10000 rows x 6 columns]
